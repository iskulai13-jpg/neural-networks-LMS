# %% [markdown]
# <a href="https://colab.research.google.com/github/iskulai13-jpg/neural-networks-LMS/blob/main/image_classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Суреттерді классификациялау (Image Classification)
#
# Бұл зертханалық жұмыста нейрондық желі көмегімен суреттерді тану процесімен танысасыз.
#
# ## Жұмыстың мақсаты
# - Нейрондық желінің жұмыс принципін түсіну
# - MNIST деректер жиынтығымен жұмыс істеу
# - Модельді оқыту және оның дәлдігін бағалау
#
#
# ## Орындау нұсқаулығы
#
# 1. Оң жақ жоғарғы бұрыштағы "Подключиться" батырмасын басыңыз
# 2. "Выполнить все" (Run all) батырмасын таңдаңыз
# 3. Барлық код ұяшықтарының орындалуын күтіңіз
# 4. Нәтижесінде модельдің дәлдігі (accuracy) экранда көрсетіледі
#
# Ескерту: Кодты өзгертпей орындау ұсынылады
#
#
# ## Тапсырма
#
# 1. Модельді іске қосыңыз
# 2. Нәтижеде шыққан дәлдік мәнін (accuracy) анықтаңыз
# 3. Epoch санын өзгертіп (мысалы, 3 → 5), нәтижені қайта салыстырыңыз
#
# ## Қорытынды сұрақтар
#
# 1. Модельдің бастапқы дәлдігі қандай болды?
# 2. Epoch санын арттырғанда нәтиже қалай өзгерді?
# 3. Нейрондық желінің дәлдігіне қандай факторлар әсер етеді?
#
# ## Қорытынды
#
# Бұл жұмыста сіз нейрондық желінің көмегімен суреттерді классификациялауды үйрендіңіз.
# Алынған нәтижелер модельдің тиімділігін бағалауға мүмкіндік береді.
# ---

# %%
# TensorFlow орнату
# !pip install tensorflow

import tensorflow as tf
from tensorflow.keras import layers, models
import matplotlib.pyplot as plt

# MNIST dataset (қолмен жазылған цифрлар)
mnist = tf.keras.datasets.mnist
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# Нормализация
x_train, x_test = x_train / 255.0, x_test / 255.0

# Модель құру
model = models.Sequential([
    layers.Flatten(input_shape=(28, 28)),
    layers.Dense(128, activation='relu'),
    layers.Dense(10, activation='softmax')
])

# Компиляция
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# Оқыту
model.fit(x_train, y_train, epochs=3)

# Бағалау
test_loss, test_acc = model.evaluate(x_test, y_test)

print("Тест дәлдігі:", test_acc)
# Out:
# ...
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/3
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.9278 - loss: 0.2551
# Epoch 2/3
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9671 - loss: 0.1115
# Epoch 3/3
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9770 - loss: 0.0766
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9700 - loss: 0.1011
# Тест дәлдігі: 0.9700000286102295
